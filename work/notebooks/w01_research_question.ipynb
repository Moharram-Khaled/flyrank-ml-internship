# %% [markdown]
# <a href="https://colab.research.google.com/github/Moharram-Khaled/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Moharram-Khaled/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# Ranking Signal Analysis
#
# I chose the Ranking Signal Analysis lane. I want to investigate which observable content and search signals are associated with page visibility, clicks, engagement, or movement. I chose this lane because the starter dataset contains several measurable signals such as impressions, clicks, CTR, average position, content age, word count, and engagement metrics. Understanding which signals show stronger relationships can help inform practical content and search decisions without relying on unsupported assumptions about Google's algorithm.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# # Search question
#
# Which observable content and search signals are most strongly associated with page visibility and movement?
#
# # Unit of analysis
#
# The unit of analysis is a content page.
#
# # Decision
#
# The analysis should help identify which observable signals are most useful to consider when evaluating a page's search performance.
#
# # Action
#
# A content or search team could use the findings to prioritize which signals to investigate when reviewing page performance and to guide further analysis or content decisions.
#
# # Cost of a wrong recommendation
#
# If a weak or misleading signal is treated as important, the team could spend time optimizing the wrong area. If an important signal is overlooked, useful opportunities for investigation could be missed. Therefore, the results should support decisions rather than automatically determine them.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# The starter dataset contains 39,341 pages. The median number of impressions over 90 days is 742, while the median average position is 10.8 and the median CTR is 0.07. The dataset also contains 21,260 pages with a downward trend, compared with 5,762 pages with an upward trend. These numbers suggest that there is enough variation in visibility, position, CTR, and trend direction to investigate which observable signals are associated with search performance and movement.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# I can identify and compare observed relationships between safe, measurable search and content signals. I can describe these relationships as directional or observational and use them to suggest areas for further investigation.
#
# I cannot claim that a signal causes better rankings, clicks, or engagement, and I cannot claim to have proved a Google ranking factor. Correlation or association in this dataset does not establish causation.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
